# %%
# QUESTION NO 01 :



class Account:
    def __init__(self, acc_no, name, balance):
        self.acc_no = acc_no
        self.balance = balance
        self.name = name

    def deposit(self, amount):
        print(f"{amount} Rs deposit successfully!")
        print(f"Account Name: {self.name}")
        print(f"Account no: {self.acc_no}")
        print(f"Previous Balance: {self.balance}")
        self.balance += amount
        print(f"New balance: {self.balance}")

    def withdraw(self, amount):
        if amount >= self.balance:
            print("Insufficient Balance")
        else:
            print(f"{amount} Rs withdraws from account.")
            print(f"Account Name: {self.name}")
            print(f"Account no: {self.acc_no}")
            print(f"Previous Balance: {self.balance}")
            self.balance -= amount
            print(f"New balance: {self.balance}")


class saving_account(Account):
    def __init__ (self,acc_no,balance,name,interest):
        super().__init__(acc_no,balance,name)
        self.interest = interest

    def interest_rate (self):
        Inrate = self.balance * (self.interest/100)
        self.balance += Inrate
        print(f" Interest Rate : {Inrate}")


class current_account(Account):
      def __init__ (self,acc_no,balance,name,overdraft_limit):
        super().__init__(acc_no,balance,name)
        self.overdraft_limit = overdraft_limit

      def check_overdraft (self,amount):
        if amount<=self.balance:
            if amount<=self.overdraft_limit:
                print('Under Draft Limit ')
        else:
            print('Draft Limit  Exceed')
            
      def withdraw(self,amount):
         if amount<=self.balance:
            if amount<=self.overdraft_limit:
                self.balance -= amount
                print(f" Balance : {self.accBal}")
            else:
                print("Draft Limit Exceed")
         else:
            print("Insufficient balance")
             
while True:
    inp = int(input("Enter 1 for Saving Account, 2 for Current Account, 0 to exit: "))
    match inp:
        case 0:
            print("Thank You")
            break        
        case 1:
            name = input("Enter Account Name: ")
            num = int(input("Enter Account Number: "))
            bal = int(input("Enter Account Balance: "))
            ir = int(input("Enter Interest Rate: "))
            sa = saving_account(name,num,bal,ir)
            sa.interest_rate()
            
        case 2:
            name = input("Enter Account Name: ")
            num = int(input("Enter Account Number: "))
            bal = int(input("Enter Account Balance: "))
            dl = int(input("Enter Draft Limit: "))
            ca = current_account(name,num,bal,dl)
            wd = int(input("Enter Withdraw Amount: "))
            ca.check_overdraft(wd)
            ca.withdraw(wd)
            
        case _:
            print("Wrong Input\n")

# %% [markdown]
# QUESTION NO # 01:

# %%
class person:
    def __init__ (self,name,age,gender):
        self.name = name
        self.age = age
        self.gender = gender

    
    def display (self):
         print(f"Name : {self.name} \nAge : {self.age}  \nGender : {self.gender}")


class student(person):
    def __init__ (self,name,age,gender,roll,Class):
        person.__init__(self,name,age,gender)
        self.roll = roll
        self.Class = Class

    def display (self):
        print(f"Name : {self.name} \nAge : {self.age}  \nGender : {self.gender} \nRoll No : {self.roll} \nClass : {self.Class}")

        
class teacher(person):
    def __init__(self,name,age,gender,subject,experience):
        person.__init__(self,name,age,gender)
        self.subject = subject
        self.experience = experience

    def display (self):
        print(f"Name : {self.name} \nAge : {self.age}  \nGender : {self.gender} \nSubject : {self.subject} \nExperience : {self.experience}")


class admin(student,teacher):
     def __init__ (self,name,age,gender,salary,position):
        person.__init__(self,name,age,gender)
        self.salary = salary
        self.position = position

     def display (self):
        print(f"Name : {self.name} \nAge : {self.age}  \nGender : {self.gender} \nSalary : {self.salary} \nPosition : {self.position}")


while True:
    choice = int(input(f" 1 For Student \n 2 For Teacher \n 3 For Admin \n 0 To Exit\n"))
    match choice:
        case 0 :
            print('______________________________________________________')
            print('Thank You!')
            print('______________________________________________________')
            break
            
        case 1 :
            Name = input('Enter Student Name : ')
            Age = int(input('Enter Student Age : '))
            Gender = input('Enter Student Gender :')
            RollNo = input('Enter Student Roll No :')
            CLass = input('Enter Student Class :')
            st = student(Name,Age,Gender,RollNo,CLass)
            print('______________________________________________________')
            st.display()
            print('______________________________________________________')

        case 2:
            Name = input('Enter Teacher Name : ')
            Age = int(input('Enter Techer Age : '))
            Gender = input('Enter Techer Gender :')
            Subject = input('Enter Teacher Subject :')
            Experience = input('Enter Teacher Experience :')
            tr = teacher(Name,Age,Gender,Subject,Experience)
            print('______________________________________________________')
            tr.display()
            print('______________________________________________________')
            
        case 3:
            Name = input('Enter Admin Name : ')
            Age = int(input('Enter Admin Age : '))
            Gender = input('Enter Admin Gender :')
            Salary = int(input('Enter Admin Salary :'))
            Position = input('Enter Position :')
            ad = (Name,Age,Gender,Salary,Position)
            print('______________________________________________________')
            ad.display()
            print('______________________________________________________')
            
        case _:
            print('Wrong Input\n')
# Out:
#  1 For Student
#  2 For Teacher
#  3 For Admin
#  0 To Exit
#  3
# Enter Admin Name :  ali
# Enter Admin Age :  21
# Enter Admin Gender : male
# Enter Admin Salary : 50000
# Enter Position : officer
# ______________________________________________________
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 81
#      79     ad = (Name,Age,Gender,Salary,Position)
#      80     print('______________________________________________________')
# ---> 81     ad.display()
#      82     print('______________________________________________________')
#      84 case _:
#
# AttributeError: 'tuple' object has no attribute 'display'
